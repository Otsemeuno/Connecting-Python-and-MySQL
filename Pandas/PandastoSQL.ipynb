# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import MySQLdb as mysql

# %%
df = pd.read_csv("train_details.csv")
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_1480\2837653163.py:1: DtypeWarning: Columns (0,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("train_details.csv")

# %%
df.isnull().sum()
# Out:
# train_no                    0
# station_code                0
# station_name                0
# arrival_time                0
# deparure_time               0
# distance                    0
# source_station_code         0
# source_station_name         0
# destination_station_code    0
# destination_station_name    0
# dtype: int64

# %%
df = df.rename(columns = {'tran_no':'train_no', 'station_sode': 'station_code', 'source_station_code.1': 'source_station_name'})

# %%
df.replace({
    'NULL': np.NaN
})
# Out:
#        train_no station_code  station_name arrival_time deparure_time  \
# 0           107          SWV  SAWANTWADI R     00:00:00      10:25:00
# 1           107         THVM        THIVIM     11:06:00      11:08:00
# 2           107         KRMI       KARMALI     11:28:00      11:30:00
# 3           107          MAO   MADGOAN JN.     12:10:00      00:00:00
# 4           108          MAO   MADGOAN JN.     00:00:00      20:30:00
# ...         ...          ...           ...          ...           ...
# 186115    99908         AKRD        AKURDI     23:30:00      23:31:00
# 186116    99908         DEHR     DEHU ROAD     23:35:00      23:36:00
# 186117    99908         BGWI     BEGDAEWAI     23:39:00      23:40:00
# 186118    99908         GRWD     GHORAWADI     23:41:00      23:42:00
# 186119    99908          TGN      TALEGAON     23:50:00      00:00:00
#
#        distance source_station_code source_station_name  \
# 0             0                 SWV     SAWANTWADI ROAD
# ...

# %%
df = df.dropna()

# %%
df.dtypes
# Out:
# train_no                    object
# station_code                object
# station_name                object
# arrival_time                object
# deparure_time               object
# distance                    object
# source_station_code         object
# source_station_name         object
# destination_station_code    object
# destination_station_name    object
# dtype: object

# %%
df = df.astype(
{
'train_no': int,
'station_code': str,
'station_name':str,
'arrival_time': 'datetime64[ns]',
'deparure_time': 'datetime64[ns]',
'distance':int,
'source_station_code': str,
'source_station_name':str,
'destination_station_code': str,
'destination_station_name': str
})

# %%
df
# Out:
#         train_no station_code  station_name        arrival_time  \
# 0            107          SWV  SAWANTWADI R 2023-01-25 00:00:00
# 1            107         THVM        THIVIM 2023-01-25 11:06:00
# 2            107         KRMI       KARMALI 2023-01-25 11:28:00
# 3            107          MAO   MADGOAN JN. 2023-01-25 12:10:00
# 4            108          MAO   MADGOAN JN. 2023-01-25 00:00:00
# ...          ...          ...           ...                 ...
# 186115     99908         AKRD        AKURDI 2023-01-25 23:30:00
# 186116     99908         DEHR     DEHU ROAD 2023-01-25 23:35:00
# 186117     99908         BGWI     BEGDAEWAI 2023-01-25 23:39:00
# 186118     99908         GRWD     GHORAWADI 2023-01-25 23:41:00
# 186119     99908          TGN      TALEGAON 2023-01-25 23:50:00
#
#              deparure_time  distance source_station_code source_station_name  \
# 0      2023-01-25 10:25:00         0                 SWV     SAWANTWADI ROAD
# ...

# %%
sqlEngine = create_engine('mysql://root:Folashade%4012@127.0.0.1/practice')

# %%
df.to_sql('MainDB', sqlEngine, index = False)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\pandas\io\sql.py:1666: UserWarning: The provided table name 'MainDB' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
# 186114
